# %% [markdown]
# # Traitement de la source de données

# %%
import os
from datetime import date, timedelta

import pandas as pd

# %%
# Racine des fichiers quotidiens
BASE_URL = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/{}.csv'

# Dates de disponibilité des fichiers
START_DATE = date(2020, 1, 22)
END_DATE = date(2020, 3, 13)

# Répertoire de sauvegarde des fichiers bruts
RAWFILES_DIR = '../data/raw/'
PROCESSED_DIR = '../data/processed/'

# Fichier principal
ALL_DATA_FILE = 'all_data.csv'

#TODO: A remplacer par la lecture du fichier env.yaml

# %% [markdown]
# ## Boucle de récupération des fichiers

# %%
delta = END_DATE - START_DATE       # as timedelta

for i in range(delta.days + 1):
    day = START_DATE + timedelta(days=i)
    day_label = day.strftime("%m-%d-%Y")
    #print(day_label)
    virus_df = pd.read_csv(BASE_URL.format(day_label), sep=',', parse_dates=['Last Update'])
    virus_df.to_csv(os.path.join(RAWFILES_DIR, day_label + '.csv'), index=False)

# %% [markdown]
# ## Constitution de la table de références lat / log

# %%
import glob

df_list = []

# Lecture des fichiers récupérés et sélection de ceux qui ont une lat / long
for file in glob.glob(os.path.join(RAWFILES_DIR, '*.csv')):
    virus_df = pd.read_csv(file, sep=',')
    if 'Latitude' in virus_df.columns and 'Longitude' in virus_df.columns:
        df_list.append(virus_df)

all_df = pd.concat(df_list)

# Création d'une table de références pour les lat/long
(all_df[['Province/State', 'Country/Region', 'Latitude', 'Longitude']]
 .drop_duplicates(subset=['Province/State', 'Country/Region'])
 .sort_values(by=['Country/Region', 'Province/State'])
 .to_csv(os.path.join(PROCESSED_DIR, 'lat_long_table.csv'), index=False)
)

# %% [markdown]
# ## Construction d'une table unique

# %%
data_catalog = {
    'Last Update': ['<M8[ns]'],
    'Confirmed': ['float64', 'int64'],
    'Deaths': ['float64', 'int64'],
    'Recovered': ['float64', 'int64'],
    'Latitude': ['float64'],
    'Longitude': ['float64'],
}

# %%
df_list = []
latlong_df = pd.read_csv(os.path.join(PROCESSED_DIR, 'lat_long_table.csv'))

# Lecture des fichiers récupérés et sélection de ceux qui ont une lat / long
for file in glob.glob(os.path.join(RAWFILES_DIR, '*.csv')):
    virus_df = pd.read_csv(file, sep=',', parse_dates=['Last Update'])
    if not('Latitude' in virus_df.columns and 'Longitude' in virus_df.columns):
        virus_df = virus_df.merge(latlong_df, on=['Province/State', 'Country/Region'], how='left')
        
    for field, types in data_catalog.items():
        assert virus_df[field].dtypes in types, f"Bad type for {field} in {file}"
        
    df_list.append(virus_df.assign(source=os.path.basename(file)))

all_df = pd.concat(df_list)

# Sauvegarde de la table totale
all_df.to_csv(os.path.join(PROCESSED_DIR, 'all_data.csv'), index=False)

# %%
all_df
# Out:
#                            Province/State  Country/Region         Last Update  \
# 0                                   Hubei  Mainland China 2020-02-26 14:13:10
# 1                               Guangdong  Mainland China 2020-02-26 10:33:02
# 2                                   Henan  Mainland China 2020-02-26 10:33:02
# 3                                     NaN     South Korea 2020-02-26 11:03:11
# 4                                Zhejiang  Mainland China 2020-02-26 10:33:02
# 5                                   Hunan  Mainland China 2020-02-26 10:13:11
# 6                                   Anhui  Mainland China 2020-02-26 10:13:11
# 7                                 Jiangxi  Mainland China 2020-02-26 01:13:04
# 8                                Shandong  Mainland China 2020-02-26 12:43:02
# 9            Diamond Princess cruise ship          Others 2020-02-26 19:33:02
# 10                                Jiangsu  Mainland China 2020-02-26 10:13:11
# 11                              Chongqing  Mainland China 2020-02-26 23:43:02
# 12                                Sichuan  Mainland China 2020-02-26 10:13:11
# 13                           Heilongjiang  Mainland China 2020-02-26 10:33:02
# 14                                    NaN           Italy 2020-02-26 23:43:03
# 15                                Beijing  Mainland China 2020-02-26 00:53:02
# 16                               Shanghai  Mainland China 2020-02-26 23:53:01
# 17                                  Hebei  Mainland China 2020-02-26 10:33:02
# 18                                 Fujian  Mainland China 2020-02-26 10:33:02
# 19                                Guangxi  Mainland China 2020-02-26 14:13:10
# 20                                Shaanxi  Mainland China 2020-02-26 14:13:10
# 21                                    NaN           Japan 2020-02-26 23:43:03
# 22                                 Yunnan  Mainland China 2020-02-26 05:13:16
# 23                                 Hainan  Mainland China 2020-02-26 12:43:02
# 24                                Guizhou  Mainland China 2020-02-25 08:03:07
# 25                                    NaN            Iran 2020-02-26 23:43:03
# 26                                Tianjin  Mainland China 2020-02-26 12:43:02
# 27                                 Shanxi  Mainland China 2020-02-26 14:13:10
# 28                               Liaoning  Mainland China 2020-02-26 00:13:05
# 29                                  Jilin  Mainland China 2020-02-26 14:13:10
# ..                                    ...             ...                 ...
# 225                   Plymouth County, MA              US 2020-03-07 03:53:03
# 226                       Polk County, GA              US 2020-03-08 04:13:22
# 227                     Ramsey County, MN              US 2020-03-06 23:23:03
# 228                  Riverside County, CA              US 2020-03-08 10:33:03
# 229                       San Antonio, TX              US 2020-02-13 18:53:02
# 230                 Santa Rosa County, FL              US 2020-03-08 15:33:04
# 231                          Sarasota, FL              US 2020-03-02 03:23:06
# 232                     Shelby County, TN              US 2020-03-08 16:13:36
# 233                     Sonoma County, CA              US 2020-03-02 20:53:02
# 234                    Spokane County, WA              US 2020-03-08 21:53:04
# 235                  St. Louis County, MO              US 2020-03-08 11:23:08
# 236                    Suffolk County, NY              US 2020-03-08 16:03:05
# 237                      Tulsa County, OK              US 2020-03-07 04:43:02
# 238                     Ulster County, NY              US 2020-03-08 16:23:07
# 239                          Umatilla, OR              US 2020-03-02 20:23:16
# 240               Unassigned Location, VT              US 2020-03-08 06:23:05
# 241                  Unknown Location, MA              US 2020-03-08 21:23:03
# 242                    Volusia County, FL              US 2020-03-08 03:03:08
# 243                       Wake County, NC              US 2020-03-03 20:53:02
# 244                      Wayne County, PA              US 2020-03-06 16:13:15
# 245                 Williamson County, TN              US 2020-03-05 23:33:03
# 246                       Yolo County, CA              US 2020-03-06 20:13:14
# 247                                   NaN         Ukraine 2020-03-03 15:33:02
# 248                                   NaN    Vatican City 2020-03-06 15:43:02
# 249                 From Diamond Princess       Australia 2020-02-29 02:03:10
# 250                    Northern Territory       Australia 2020-03-06 04:33:03
# 251  Lackland, TX (From Diamond Princess)              US 2020-02-24 23:33:02
# 252                 Montgomery County, TX              US 2020-03-07 19:53:02
# 253     Omaha, NE (From Diamond Princess)              US 2020-02-24 23:33:02
# 254    Travis, CA (From Diamond Princess)              US 2020-02-24 23:33:02
#
#      Confirmed  Deaths  Recovered  Latitude  Longitude          source
# 0      65187.0  2615.0    20969.0   30.9756   112.2707  02-26-2020.csv
# 1       1347.0     7.0      851.0   23.3417   113.4244  02-26-2020.csv
# 2       1271.0    19.0     1033.0   33.8820   113.6140  02-26-2020.csv
# 3       1261.0    12.0       22.0   36.0000   128.0000  02-26-2020.csv
# 4       1205.0     1.0      867.0   29.1832   120.0934  02-26-2020.csv
# 5       1016.0     4.0      783.0   27.6104   111.7088  02-26-2020.csv
# 6        989.0     6.0      744.0   31.8257   117.2264  02-26-2020.csv
# 7        934.0     1.0      719.0   27.6140   115.7221  02-26-2020.csv
# 8        756.0     6.0      377.0   36.3427   118.1498  02-26-2020.csv
# 9        705.0     4.0       10.0   35.4437   139.6380  02-26-2020.csv
# 10       631.0     0.0      478.0   32.9711   119.4550  02-26-2020.csv
# 11       576.0     6.0      384.0   30.0572   107.8740  02-26-2020.csv
# 12       531.0     3.0      307.0   30.6171   102.7103  02-26-2020.csv
# 13       480.0    12.0      249.0   47.8620   127.7615  02-26-2020.csv
# 14       453.0    12.0        3.0   43.0000    12.0000  02-26-2020.csv
# 15       400.0     4.0      235.0   40.1824   116.4142  02-26-2020.csv
# 16       337.0     3.0      272.0   31.2020   121.4491  02-26-2020.csv
# 17       312.0     6.0      261.0   38.0428   114.5149  02-26-2020.csv
# 18       294.0     1.0      218.0   26.0789   117.9874  02-26-2020.csv
# 19       252.0     2.0      147.0   23.8298   108.7881  02-26-2020.csv
# 20       245.0     1.0      192.0   35.1917   108.8701  02-26-2020.csv
# 21       189.0     2.0       22.0   36.0000   138.0000  02-26-2020.csv
# 22       174.0     2.0      144.0   24.9740   101.4870  02-26-2020.csv
# 23       168.0     5.0      129.0   19.1959   109.7453  02-26-2020.csv
# 24       146.0     2.0      104.0   26.8154   106.8748  02-26-2020.csv
# 25       139.0    19.0       49.0   32.0000    53.0000  02-26-2020.csv
# 26       135.0     3.0       96.0   39.3054   117.3230  02-26-2020.csv
# 27       133.0     0.0      104.0   37.5777   112.2922  02-26-2020.csv
# 28       121.0     1.0       88.0   41.2956   122.6085  02-26-2020.csv
# 29        93.0     1.0       65.0   43.6661   126.1923  02-26-2020.csv
# ..         ...     ...        ...       ...        ...             ...
# 225        1.0     0.0        0.0   42.1615   -70.7928  03-08-2020.csv
# 226        1.0     0.0        0.0   34.0132   -85.1479  03-08-2020.csv
# 227        1.0     0.0        0.0   44.9964   -93.0616  03-08-2020.csv
# 228        1.0     0.0        0.0   33.9533  -117.3961  03-08-2020.csv
# 229        1.0     0.0        0.0   29.4241   -98.4936  03-08-2020.csv
# 230        1.0     1.0        0.0   30.7690   -86.9824  03-08-2020.csv
# 231        1.0     0.0        0.0   27.3364   -82.5307  03-08-2020.csv
# 232        1.0     0.0        0.0   35.1269   -89.9253  03-08-2020.csv
# 233        1.0     0.0        0.0   38.5780  -122.9888  03-08-2020.csv
# 234        1.0     0.0        0.0   47.6587  -117.4225  03-08-2020.csv
# 235        1.0     0.0        0.0   38.6103   -90.4125  03-08-2020.csv
# 236        1.0     0.0        0.0   40.9849   -72.6151  03-08-2020.csv
# 237        1.0     0.0        0.0   36.1593   -95.9410  03-08-2020.csv
# 238        1.0     0.0        0.0   41.8586   -74.3118  03-08-2020.csv
# 239        1.0     0.0        0.0   45.7750  -118.7606  03-08-2020.csv
# 240        1.0     0.0        0.0   44.3378   -72.7563  03-08-2020.csv
# 241        1.0     0.0        0.0   42.4072   -71.3824  03-08-2020.csv
# 242        1.0     0.0        0.0   29.0280   -81.0755  03-08-2020.csv
# 243        1.0     0.0        0.0   35.8032   -78.5661  03-08-2020.csv
# 244        1.0     0.0        0.0   41.6739   -75.2479  03-08-2020.csv
# 245        1.0     0.0        0.0   35.9179   -86.8622  03-08-2020.csv
# 246        1.0     0.0        0.0   38.7646  -121.9018  03-08-2020.csv
# 247        1.0     0.0        0.0   48.3794    31.1656  03-08-2020.csv
# 248        1.0     0.0        0.0   41.9029    12.4534  03-08-2020.csv
# 249        0.0     0.0        0.0   35.4437   139.6380  03-08-2020.csv
# 250        0.0     0.0        0.0  -12.4634   130.8456  03-08-2020.csv
# 251        0.0     0.0        0.0   29.3829   -98.6134  03-08-2020.csv
# 252        0.0     0.0        0.0   30.3213   -95.4778  03-08-2020.csv
# 253        0.0     0.0        0.0   41.2545   -95.9758  03-08-2020.csv
# 254        0.0     0.0        0.0   38.2721  -121.9399  03-08-2020.csv
#
# [5383 rows x 9 columns]
